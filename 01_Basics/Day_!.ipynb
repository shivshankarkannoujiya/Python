# %%
import this # GIve some short description about Python
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
print("Hello World")
# Out:
# Hello World

# %%
#print "hello world" :- [ works in  2.X code ]

# %%
12+56
# Out:
# 68

# %%
print(12-23)
# Out:
# -11

# %%
print(12+12);
# Out:
# 24

# %%
12/4
# Out:
# 3.0

# %% [markdown]
# VARIABLE

# %%
a =10  # a :-  variable
rock = 12
print(a)
rock   # can print  directly
# Out:
# 10
# 12

# %% [markdown]
# TYPE OF VARIABLE :  type(object) -> the object's type

# %%
type(a)
# Out:
# int

# %%
b = 12.5
type(b)
# Out:
# float

# %%
c = "Abhi"  # using double quote 
type(c)
# Out:
# str

# %%
d = 'Abhi'
type(d)
# Out:
# str

# %%
# complexNum = realPart + maginaryPart : [j --> used to represent maginaryPart]
complex_num = 5+6j
print(complex_num)
type(complex_num)
# Out:
# (5+6j)
# complex

# %%
name = "asdfghjklqwertyulsdhfgfdhfgysefgygrfdf"
name
# Out:
# 'asdfghjklqwertyulsdhfgfdhfgysefgygrfdf'

# %%
g = True  # Boolean : True/False
type(g)
# Out:
# bool

# %%
_a = 34
_a
# Out:
# 34

# %%
a,b,c,d,e = 12,12.5,True,"Abhi",23+7j

# %%
a,b,c,d,e
# Out:
# (12, 12.5, True, 'Abhi', (23+7j))

# %% [markdown]
# 1. HOW TO ACCESS [REAL PART] AND [IMAGINARY PART] SEPRATELY FROM COMPLEX NUMBER ?

# %%
v = 11+12j
v.imag  # return imaginaryPart
# Out:
# 12.0

# %%
v.real # return Real Part
# Out:
# 11.0

# %% [markdown]
# TYPECASTING

# %%
add = "Abhi"+str(10100000)
add
# Out:
# 'Abhi10100000'

# %%
True+True  # [True == 1]
# Out:
# 2

# %%
True+False # [False == 0]
# Out:
# 1

# %%
1+True
# Out:
# 2

# %%
0+False
# Out:
# 0

# %%
True-False
# Out:
# 1

# %% [markdown]
# USER_INPUT

# %%
input()  # By Default it return STRING
# Out:
# abhisgdf
# 'abhisgdf'

# %%
a = input()
# Out:
# Abhishek

# %%
num = input()
# Out:
# 123456

# %%
num
# Out:
# '123456'

# %%
Num1 = int(input("Enter the value : "))
# Out:
# Enter the value : 1234567890

# %%
Num1  # Printing
# Out:
# 1234567890

# %%
pwd() # Present WOrking Directory
# Out:
# 'P:\\Pro\\Python_Fundamental'

# %%
complex = 12+3j

# %%
complex.conjugate()
# Out:
# (12-3j)
